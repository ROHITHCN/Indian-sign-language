# %%
# %%
import keras
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Dropout, LSTM, Activation, BatchNormalization
from keras import Sequential
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import pickle
import cv2
import mediapipe as mp
import numpy as np
import os
import copy
import itertools

# %%
dataset = "D:\isl_projects\datasets"

classList = ['dry', 'healthy', 'sick']
print(len(classList))

# %%
hands = mp.solutions.hands.Hands(static_image_mode=False, max_num_hands=2,
                                 min_detection_confidence=0.5, min_tracking_confidence=0.5)
sequenceLength = 30
# Out:
# 3

# %%
def normalizeCoordinates(coords):

    baseX = 0
    baseY = 0

    for i, val in enumerate(coords):
        if i == 0:
            baseX = val[0]
            baseY = val[1]

        coords[i][0] = coords[i][0] - baseX
        coords[i][1] = coords[i][1] - baseY

    coords = list(itertools.chain.from_iterable(coords))

    maxVal = max(list(map(abs, coords)))

    def normalize_(n):
        return n / maxVal

    coords = list(map(normalize_, coords))

    return coords

# %%
def skeletonExtraction(path):

    left = []
    right = []
    cap = cv2.VideoCapture(path)

    while True:
        success, img = cap.read()

        if (success == False):

            cap.release()
            break

        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = hands.process(imgRGB)

        hLeft = None
        hRight = None

        if (results.multi_hand_landmarks):
            for idx, handLms in enumerate(results.multi_hand_landmarks):

                hand = []
                for id, lm in enumerate(handLms.landmark):
                    h, w, c = img.shape
                    cx, cy = int(lm.x * w), int(lm.y*h)
                    hand.append([cx, cy])

                label = results.multi_handedness[idx].classification[0].label

                if (label == 'Left'):
                    hLeft = normalizeCoordinates(hand)
                elif (label == 'Right'):
                    hRight = normalizeCoordinates(hand)

        if (hLeft != None):
            left.append(hLeft)
        if (hRight != None):
            right.append(hRight)

    countLeft = len(left)
    countRight = len(right)
    windowLeft = max(countLeft/sequenceLength, 1)
    windowRight = max(countRight/sequenceLength, 1)

    finalFeatures = []

    if countLeft < sequenceLength or countRight < sequenceLength:
        return []

    for i in range(0, sequenceLength):

        finalFeatures.append(
            left[int(i * windowLeft)] + right[int(i * windowRight)])

    return np.asarray(finalFeatures)

# %%
def createDataset():

    features = []
    labels = []
    paths = []

    for index, name in enumerate(classList):
        filesList = os.listdir(os.path.join(dataset, name))

        for i in filesList:

            path = os.path.join(dataset, name, i)

            extractedFeatures = skeletonExtraction(path)

            if (len(extractedFeatures) == sequenceLength):
                features.append(extractedFeatures)
                labels.append(index)
                paths.append(path)

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels, paths

# %%
features, labels, paths = createDataset()

# %%
encodedLabels = to_categorical(labels)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    features, encodedLabels, test_size=0.01, random_state=69)


# %%
x_train.shape

# %%

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(30, 84)))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(LSTM(256))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

# %%

# %%
earlyStopping = EarlyStopping(
    monitor='val_loss', patience=10, mode='min', restore_best_weights=True)
model.fit(x=x_train, y=y_train, epochs=50, validation_split=0.2)

# %%
modelEvaluate = model.evaluate(x_test, y_test)

# %%
model.save_weights("my.h5")
modelJSON = model.to_json()
with open('my.json', 'w') as jsonFile:
    jsonFile.write(modelJSON)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 5s 816ms/step - loss: 0.9504 - accuracy: 0.5455 - val_loss: 1.0433 - val_accuracy: 0.5000
# Epoch 2/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6993 - accuracy: 0.6591 - val_loss: 1.0041 - val_accuracy: 0.5833
# Epoch 3/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.3848 - accuracy: 0.9318 - val_loss: 0.9370 - val_accuracy: 0.7500
# Epoch 4/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.2189 - accuracy: 0.9091 - val_loss: 0.8226 - val_accuracy: 0.7500
# Epoch 5/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0892 - accuracy: 0.9773 - val_loss: 0.6816 - val_accuracy: 0.9167
# Epoch 6/50
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.5519 - val_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.3960 - val_accuracy: 0.9167
# Epoch 9/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.3503 - val_accuracy: 0.9167
# Epoch 10/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3183 - val_accuracy: 0.9167
# Epoch 11/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.2974 - val_accuracy: 0.9167
# Epoch 12/50
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3024 - val_accuracy: 0.9167
# Epoch 13/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2356 - val_accuracy: 0.9167
# Epoch 14/50
# 2/2 [==============================] - 0s 79ms/step - loss: 7.4608e-04 - accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 94ms/step - loss: 8.6355e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 94ms/step - loss: 7.1048e-04 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 94ms/step - loss: 4.9704e-04 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 94ms/step - loss: 5.2530e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 80ms/step - loss: 4.1438e-04 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 126ms/step - loss: 2.1030e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9167
# Epoch 25/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.1455 - accuracy: 0.9773 - val_loss: 0.0518 - val_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 173ms/step - loss: 1.0996e-04 - accuracy: 1.0000 - val_loss: 0.8280 - val_accuracy: 0.6667
# Epoch 27/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.8790 - accuracy: 0.7727 - val_loss: 0.8506 - val_accuracy: 0.6667
# Epoch 28/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.4806 - accuracy: 0.7955 - val_loss: 0.9049 - val_accuracy: 0.6667
# Epoch 29/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.9400 - accuracy: 0.7273 - val_loss: 0.6005 - val_accuracy: 0.6667
# Epoch 30/50
# 2/2 [==============================] - 0s 172ms/step - loss: 0.1510 - accuracy: 0.9318 - val_loss: 0.6110 - val_accuracy: 0.6667
# Epoch 31/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.1095 - accuracy: 0.9773 - val_loss: 0.6154 - val_accuracy: 0.6667
# Epoch 32/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.1211 - accuracy: 0.9318 - val_loss: 0.5575 - val_accuracy: 0.6667
# Epoch 33/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.4921 - val_accuracy: 0.7500
# Epoch 34/50
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.4392 - val_accuracy: 0.9167
# Epoch 35/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.3962 - val_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0465 - accuracy: 0.9773 - val_loss: 0.3533 - val_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0324 - accuracy: 0.9773 - val_loss: 0.3236 - val_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.3497 - val_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0462 - accuracy: 0.9773 - val_loss: 0.2832 - val_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2524 - val_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2206 - val_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1724 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 97ms/step - loss: 7.5322e-04 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 94ms/step - loss: 6.9238e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0124 - accuracy: 1.0000

# %%
def inputProcessing(path):
    features = skeletonExtraction(path)
    temp = [features]

    return np.asarray(temp)

# %%
features = inputProcessing("D:\isl_projects\datasets\Dry\MVI_5167.MOV")
output = model.predict(features)
label = classList[np.argmax(output)]
print(label)
# Out:
# 1/1 [==============================] - 1s 674ms/step
# dry

# %%
jsonFile = open('my.json', 'r')
loadedModel = jsonFile.read()
loadedModel = keras.models.model_from_json(loadedModel)
loadedModel.load_weights('my.h5')
loadedModel.compile(loss='categorical_crossentropy',
                    optimizer='adam', metrics=['accuracy'])

# %%
features = inputProcessing("D:\isl_projects\datasets\Healthy\MVI_5173.MOV")
output = loadedModel.predict(features)
label = classList[np.argmax(output)]
print(label)
# Out:
# 1/1 [==============================] - 1s 674ms/step
# healthy
