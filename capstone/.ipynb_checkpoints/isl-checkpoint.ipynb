# %%
import cv2
import mediapipe as mp
import numpy as np
import os
import copy
import itertools

# %%
#from streamlit_webrtc import webrtc_streamer

# %%
, 'Artist', 'Attack', 'Author', 'Baby', 'Bad', 'Bag', 'Ball', 'Bank', 'Bathroom', 'Bed', 'Bedroom', 'Bicycle', 'Big', 'Bill', 'Bird', 'Boat', 'Book', 'Box', 'Boy', 'Brother', 'Bus', 'Car', 'Card', 'Cat', 'Chair', 'Child', 'City', 'Cold', 'Cool', 'Court', 'Cow', 'Crowd', 'Daughter', 'Death', 'Dirty', 'Doctor', 'Dog', 'Door', 'Dream', 'Dry', 'Election', 'Energy', 'Ex. Monsoon', 'Exercise', 'Expensive', 'Fall', 'Family', 'Famous', 'Fast', 'Father', 'Female', 'Fish', 'Flat', 'Friend', 'Gift', 'Girl', 'God', 'Good', 'Grandfather', 'Grandmother', 'Ground', 'Gun', 'Happy', 'Hard', 'He', 'Healthy', 'Heavy', 'High', 'Horse', 'Hospital', 'Hot', 'House', 'Husband', 'I', 'India', 'It', 'Job', 'Key', 'King', 'Kitchen', 'Lawyer', 'Letter', 'Library', 'Light', 'Location', 'Lock', 'Long', 'Loose', 'Loud', 'Low', 'Male', 'Man', 'Manager', 'Market', 'Marriage', 'Mean', 'Medicine', 'Money', 'Mother', 'Mouse', 'Narrow', 'Neighbour', 'New', 'Newspaper', 'Nice', 'Office', 'Old', 'Page', 'Paint', 'Paper', 'Parent', 'Park', 'Patient', 'Peace', 'Pen', 'Pencil', 'Photograph', 'Plane', 'Player', 'Police', 'Poor', 'President', 'Price', 'Priest', 'Queen', 'Quiet', 'Race (ethnicity)', 'Religion', 'Reporter', 'Restaurant', 'Rich', 'Ring', 'Sad', 'School', 'Science', 'Season', 'Secretary', 'Shallow', 'She', 'Shop', 'Short', 'Sick', 'Sign', 'Sister', 'Slow', 'Small', 'Soap', 'Soft', 'Soldier', 'Son', 'Sport', 'Spring', 'Street or Road', 'Strong', 'Student', 'Summer', 'Table', 'Tall', 'Teacher', 'Team', 'Technology', 'Telephone', 'Temple', 'They', 'Thick', 'Thin', 'Tight', 'Tool', 'Train', 'Train Station', 'Train ticket', 'Transportation', 'Truck', 'Ugly', 'University', 'Waiter', 'War', 'Warm', 'We', 'Weak', 'Wet', 'Wide', 'Wife', 'Window', 'Winter', 'Woman', 'You', 'You (plural)', 'Young']

# %%
dataset = r"D:\isl_projects\datasets"
#classList = ['Actor', 'Adult', 'Animal', 'Artist', 'Attack', 'Author', 'Baby', 'Bad', 'Bag', 'Ball', 'Bank', 'Bathroom', 'Bed', 'Bedroom', 'Bicycle', 'Big', 'Bill', 'Bird', 'Boat', 'Book', 'Box', 'Boy', 'Brother', 'Bus', 'Car', 'Card', 'Cat', 'Chair', 'Child', 'City', 'Cold', 'Cool', 'Court', 'Cow', 'Crowd', 'Daughter', 'Death', 'Dirty', 'Doctor', 'Dog', 'Door', 'Dream', 'Dry', 'Election', 'Energy', 'Ex. Monsoon', 'Exercise', 'Expensive', 'Fall', 'Family', 'Famous', 'Fast', 'Father', 'Female', 'Fish', 'Flat', 'Friend', 'Gift', 'Girl', 'God', 'Good', 'Grandfather', 'Grandmother', 'Ground', 'Gun', 'Happy', 'Hard', 'He', 'Healthy', 'Heavy', 'High', 'Horse', 'Hospital', 'Hot', 'House', 'Husband', 'I', 'India', 'It', 'Job', 'Key', 'King', 'Kitchen', 'Lawyer', 'Letter', 'Library', 'Light', 'Location', 'Lock', 'Long', 'Loose', 'Loud', 'Low', 'Male', 'Man', 'Manager', 'Market', 'Marriage', 'Mean', 'Medicine', 'Money', 'Mother', 'Mouse', 'Narrow', 'Neighbour', 'New', 'Newspaper', 'Nice', 'Office', 'Old', 'Page', 'Paint', 'Paper', 'Parent', 'Park', 'Patient', 'Peace', 'Pen', 'Pencil', 'Photograph', 'Plane', 'Player', 'Police', 'Poor', 'President', 'Price', 'Priest', 'Queen', 'Quiet', 'Race (ethnicity)', 'Religion', 'Reporter', 'Restaurant', 'Rich', 'Ring', 'Sad', 'School', 'Science', 'Season', 'Secretary', 'Shallow', 'She', 'Shop', 'Short', 'Sick', 'Sign', 'Sister', 'Slow', 'Small', 'Soap', 'Soft', 'Soldier', 'Son', 'Sport', 'Spring', 'Street or Road', 'Strong', 'Student', 'Summer', 'Table', 'Tall', 'Teacher', 'Team', 'Technology', 'Telephone', 'Temple', 'They', 'Thick', 'Thin', 'Tight', 'Tool', 'Train', 'Train Station', 'Train ticket', 'Transportation', 'Truck', 'Ugly', 'University', 'Waiter', 'War', 'Warm', 'We', 'Weak', 'Wet', 'Wide', 'Wife', 'Window', 'Winter', 'Woman', 'You', 'You (plural)', 'Young']
classList = ['dry', 'healthy', 'sick','Good Morning']
print(len(classList))
# Out:
# 4

# %%
hands = mp.solutions.hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5, min_tracking_confidence=0.5)
sequenceLength = 30

# %%
def normalizeCoordinates(coords):
    
    baseX = 0
    baseY = 0

    for i, val in enumerate(coords):
        if i == 0:
            baseX = val[0]
            baseY = val[1]

        coords[i][0] = coords[i][0] - baseX
        coords[i][1] = coords[i][1] - baseY 

    coords = list(itertools.chain.from_iterable(coords))

    maxVal = max(list(map(abs, coords)))

    def normalize_(n):
        return n / maxVal

    coords = list(map(normalize_, coords))

    return coords

# %%
left = []
right = []
hands = mp_hands.Hands() # initialize the MediaPipe Hands object

cap = cv2.VideoCapture(0) # Create a video capture object using the default camera (index 0)

while True:
    success, img = cap.read() # Capture a frame from the video stream
    if not success:
        print("Error capturing frame.")
        break
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)
    hLeft = None
    hRight = None
    if (results.multi_hand_landmarks):
        for idx, handLms in enumerate(results.multi_hand_landmarks):
            hand = []
            for id, lm in enumerate(handLms.landmark):
                h, w, c = img.shape
                cx, cy = int(lm.x * w), int(lm.y*h)
                hand.append([cx, cy])
            label = results.multi_handedness[idx].classification[0].label
            if (label == 'Left'):
                hLeft = normalizeCoordinates(hand)
            elif (label == 'Right'):
                hRight = normalizeCoordinates(hand)
    if (hLeft != None):
        left.append(hLeft)
    if (hRight != None):
        right.append(hRight)
countLeft = len(left)
countRight = len(right)
windowLeft = max(countLeft/sequenceLength, 1)
windowRight = max(countRight/sequenceLength, 1)
finalFeatures = []
if countLeft < sequenceLength or countRight < sequenceLength:
    return []
for i in range(0, sequenceLength):
    finalFeatures.append(
        left[int(i * windowLeft)] + right[int(i * windowRight)])

print(np.asarray(finalFeatures))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 left = []
#       2 right = []
# ----> 3 hands = mp_hands.Hands() # initialize the MediaPipe Hands object
#       5 cap = cv2.VideoCapture(0) # Create a video capture object using the default camera (index 0)
#       7 while True:
#
# NameError: name 'mp_hands' is not defined

# %%
def skeletonExtraction(path):

    left = []
    right = []
    cap = cv2.VideoCapture(path)

    while True:
        success, img = cap.read()

        if(success == False):

            cap.release()
            break
        
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = hands.process(imgRGB)
        
        hLeft = None
        hRight = None

        if(results.multi_hand_landmarks):
            for idx, handLms in enumerate(results.multi_hand_landmarks):
                
                hand = []
                for id, lm in enumerate(handLms.landmark):
                    h, w, c = img.shape
                    cx, cy = int(lm.x *w), int(lm.y*h)
                    hand.append([cx, cy])

                label = results.multi_handedness[idx].classification[0].label
                

                if(label == 'Left'):
                    hLeft = normalizeCoordinates(hand)
                elif(label == 'Right'):
                    hRight = normalizeCoordinates(hand)
        
        if(hLeft != None):
            left.append(hLeft)
        if(hRight != None):
            right.append(hRight)
    
    countLeft = len(left)
    countRight = len(right)
    windowLeft = max(countLeft/sequenceLength, 1)
    windowRight = max(countRight/sequenceLength, 1)

    finalFeatures = []

    if countLeft < sequenceLength or countRight < sequenceLength:
        return []


    for i in range(0, sequenceLength):
        
        finalFeatures.append(left[int(i * windowLeft)] + right[int(i * windowRight)])

    return np.asarray(finalFeatures)

# %%
for index, name in enumerate(classList):
    filesList = os.listdir(os.path.join(dataset, name))
print(index)
print(name)
print(filesList)
features = []
labels = []
paths = []
for i in filesList:
    path = os.path.join(dataset, name, i)
    extractedFeatures = skeletonExtraction(path)
    if(len(extractedFeatures) == sequenceLength):
        features.append(extractedFeatures)
        labels.append(index)
        paths.append(path)
features = np.asarray(features)
labels = np.array(labels)
print("features")
print(features)
print('labels')
print(labels)
print('paths')
print(paths)
# Out:
# 3
# Good Morning
# ['MVI_0042.MOV', 'MVI_0043.MOV', 'MVI_0044.MOV', 'MVI_0045.MOV', 'MVI_0046.MOV', 'MVI_0047.MOV', 'MVI_0048.MOV', 'MVI_0098.MOV', 'MVI_0099.MOV', 'MVI_0100.MOV', 'MVI_9932.MOV', 'MVI_9933.MOV', 'MVI_9934.MOV', 'MVI_9935.MOV', 'MVI_9968.MOV', 'MVI_9969.MOV', 'MVI_9970.MOV', 'MVI_9971.MOV', 'MVI_9991.MOV', 'MVI_9992.MOV', 'MVI_9993.MOV']
# features
# [[[ 0.          0.          0.24742268 ...  0.75700935 -0.24299065
#     0.72897196]
#   [ 0.          0.          0.25263158 ...  0.68468468 -0.23423423
#     0.63063063]
#   [ 0.          0.          0.26041667 ...  0.68421053 -0.28070175
MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_0043.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_0044.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_0045.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_0046.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_0047.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_0048.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_0099.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_0100.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9932.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9933.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9934.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9935.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9968.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9969.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9970.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9971.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9991.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9992.MOV', 'D:\\isl_projects\\datasets\\Good Morning\\MVI_9993.MOV']

# %%
print(len(filesList))
print(len(labels))
print(len(paths))
# Out:
# 21
# 20
# 20

# %%
def createDataset():

    features = []
    labels = []
    paths = []
    
    for index, name in enumerate(classList):
        filesList = os.listdir(os.path.join(dataset, name))

        for i in filesList:

            path = os.path.join(dataset, name, i)

            extractedFeatures = skeletonExtraction(path)

            if(len(extractedFeatures) == sequenceLength):
                features.append(extractedFeatures)
                labels.append(index)
                paths.append(path)
    
    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels, paths

# %%
features, labels, paths = createDataset()

# %%
import pickle
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# %%
#featuresFile = open('features', 'rb')
#labelsFile = open('labels', 'rb')
#pathsFile = open('paths', 'rb')
#features = pickle.load(featuresFile)
#labels = pickle.load(labelsFile)
#paths = pickle.load(pathsFile)
#featuresFile.close()
#labelsFile.close()
#pathsFile.close()

# %%
encodedLabels = to_categorical(labels)

# %%
x_train, x_test, y_train, y_test = train_test_split(features, encodedLabels, test_size=0.2, random_state=69)

# %%
x_train.shape
# Out:
# (38, 30, 84)

# %%
import tensorflow as tf
from keras import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation, BatchNormalization

# %%
model = Sequential()
model.add(LSTM(128, return_sequences = True, input_shape = (30, 84)))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(LSTM(256))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

# %%
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)
model.fit(x = x_train, y = y_train, epochs=250, validation_split = 0.2)
# Out:
# Epoch 1/250
# 1/1 [==============================] - 10s 10s/step - loss: 1.3143 - accuracy: 0.3000 - val_loss: 1.0361 - val_accuracy: 0.7500
# Epoch 2/250
# 1/1 [==============================] - 0s 192ms/step - loss: 0.4577 - accuracy: 0.9333 - val_loss: 0.9751 - val_accuracy: 0.7500
# Epoch 3/250
# 1/1 [==============================] - 0s 250ms/step - loss: 0.3521 - accuracy: 0.8667 - val_loss: 0.9157 - val_accuracy: 0.7500
# Epoch 4/250
# 1/1 [==============================] - 0s 250ms/step - loss: 0.1695 - accuracy: 0.9333 - val_loss: 0.8623 - val_accuracy: 1.0000
# Epoch 5/250
# 1/1 [==============================] - 0s 240ms/step - loss: 0.1299 - accuracy: 0.9667 - val_loss: 0.8124 - val_accuracy: 1.0000
# Epoch 6/250
# 1/1 [==============================] - 0s 245ms/step - loss: 0.0622 - accuracy: 1.0000 - val_loss: 0.7633 - val_accuracy: 1.0000
# Epoch 7/250
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.7133 - val_accuracy: 1.0000
# Epoch 8/250
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.6634 - val_accuracy: 1.0000
# Epoch 9/250
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.6163 - val_accuracy: 1.0000
# Epoch 10/250
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5731 - val_accuracy: 1.0000
# Epoch 11/250
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.5313 - val_accuracy: 1.0000
# Epoch 12/250
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4936 - val_accuracy: 1.0000
# Epoch 13/250
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 1.0000
# Epoch 14/250
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 1.0000
# Epoch 15/250
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4076 - val_accuracy: 1.0000
# Epoch 16/250
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3857 - val_accuracy: 1.0000
# Epoch 17/250
# 1/1 [==============================] - 0s 240ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.3609 - val_accuracy: 1.0000
# Epoch 18/250
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3369 - val_accuracy: 1.0000
# Epoch 19/250
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.3079 - val_accuracy: 1.0000
# Epoch 20/250
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2854 - val_accuracy: 1.0000
# Epoch 21/250
# 1/1 [==============================] - 0s 243ms/step - loss: 8.4214e-04 - accuracy: 1.0000 - val_loss: 0.2682 - val_accuracy: 1.0000
# Epoch 22/250
# 1/1 [==============================] - 0s 235ms/step - loss: 3.8106e-04 - accuracy: 1.0000 - val_loss: 0.2545 - val_accuracy:
-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 250/250
# 1/1 [==============================] - 0s 253ms/step - loss: 1.2648e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000

# %%
modelEvaluate = model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0917 - accuracy: 0.9000

# %%
model.save_weights("modelskeleton8.h5")
modelJSON = model.to_json()
with open('modelskeleton8.json', 'w') as jsonFile:
    jsonFile.write(modelJSON)

# %% [markdown]
# model 7 used 0.15 test train and 0.15 train validation split
# model 8 used 0.01 test train and 0.2 train validation split

# %%
def inputProcessing(path):
    featuress = skeletonExtraction(path)
    temp = [featuress]

    return np.asarray(temp)

# %%
featuress = inputProcessing(r"D:\isl_projects\datasets\Actor\MVI_4516.MOV")
outputs = model.predict(features)
labels = classList[outputs]
print(labels)
# Out:
# 2/2 [==============================] - 0s 40ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 featuress = inputProcessing(r"D:\isl_projects\datasets\Actor\MVI_4516.MOV")
#       2 outputs = model.predict(features)
# ----> 3 labels = classList[outputs]
#       4 print(labels)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
import keras

# %%
jsonFile = open('modelskeleton8.json', 'r')
loadedModel = jsonFile.read()
loadedModel = keras.models.model_from_json(loadedModel)
loadedModel.load_weights('modelskeleton8.h5')
loadedModel.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 3
#       1 jsonFile = open('modelskeleton8.json', 'r')
#       2 loadedModel = jsonFile.read()
# ----> 3 print(loadedModel.shape())
#       4 loadedModel = keras.models.model_from_json(loadedModel)
#       5 loadedModel.load_weights('modelskeleton8.h5')
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
def predict(file_path):
    jsonFile = open('my.json', 'r')
    loadedModel = jsonFile.read()
    loadedModel = keras.models.model_from_json(loadedModel)
    loadedModel.load_weights('my.h5')
    loadedModel.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    featuress = inputProcessing(file_path)
    outpus = loadedModel.predict(featuress)
    labels = classList[np.argmax(outputs)]
    print(labels)
# Out:
# array([], shape=(1, 0), dtype=float64)

# %%
from tkinter import *
from tkvideoutils import VideoRecorder
from tkinter import messagebox


def merge_sources():
    if player.merge_sources(merged_path, ffmpeg_exe):
        print("Sources merged!")
    else:
        print("Something went wrong")


def stop_recording():
    player.stop_recording()
    player.stop_playback()
    button['command'] = merge_sources


def start_recording():
    player.start_recording()
    button['command'] = stop_recording


if __name__ == '__main__':
    # create instance of window
    root = Tk()
    # set window title
    root.title('Video Player')
    # load images
    pause_image = PhotoImage(file=r"C:/Users/91790/Desktop/pause.webp")
    play_image = PhotoImage(file=r"C:/Users/91790/Desktop/pause.webp")
    # create user interface
    button = Button(root, image=play_image)
    video_label = Label(root)
    video_path = 'raw_video.mp4'
    audio_path = 'recorded_video.wav'
    merged_path = 'recorded_video.mp4'
    # place elements
    video_label.pack()
    button.pack()
    # Get existing video sources
    video_sources = VideoRecorder.get_video_sources()
    audio_sources = VideoRecorder.get_audio_sources()
    print(video_sources, audio_sources)
    # TODO: Fill out FFMPEG path
    ffmpeg_exe = r''

    if video_sources:
        if video_path:
            # read video to display on label
            player = VideoRecorder(video_source=video_sources[0], audio_source=audio_sources[1],
                                   video_path=video_path, audio_path=audio_path, fps=8, label=video_label,
                                   size=(700, 500))
            player.start_playback()
        else:
            messagebox.showwarning("Select Video File", "Please retry and select a video file.")
            sys.exit(1)
        button.config(command=start_recording)
        root.mainloop()
    else:
        print("No video sources found!")
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[4], line 30
#      28 root.title('Video Player')
#      29 # load images
# ---> 30 pause_image = PhotoImage(file=r"C:/Users/91790/Desktop/pause.webp")
#      31 play_image = PhotoImage(file=r"C:/Users/91790/Desktop/pause.webp")
#      32 # create user interface
#
# File D:\softwares\python310.5\lib\tkinter\__init__.py:4093, in PhotoImage.__init__(self, name, cnf, master, **kw)
#    4088 def __init__(self, name=None, cnf={}, master=None, **kw):
#    4089     """Create an image with NAME.
#    4090
#    4091     Valid resource names: data, format, file, gamma, height, palette,
#    4092     width."""
# -> 4093     Image.__init__(self, 'photo', name, cnf, master, **kw)
#
# File D:\softwares\python310.5\lib\tkinter\__init__.py:4038, in Image.__init__(self, imgtype, name, cnf, master, **kw)
#    4036         v = self._register(v)
#    4037     options = options + ('-'+k, v)
# -> 4038 self.tk.call(('image', 'create', imgtype, name,) + options)
#    4039 self.name = name
#
# TclError: couldn't recognize data in image file "C:/Users/91790/Desktop/pause.webp"

# %%
import tkinter as tk
import os
from tkinter import filedialog
from PIL import Image, ImageTk
import cv2


#This function should call the Python program that records webcam video using OpenCV.
def record_video():
    os.system('C:/Users/91790/Desktop/record.py')

#Tkinter window and a button to it.
root = tk.Tk()
# set the size of the window
root.geometry("800x600")
def choose_file():
    file_path = filedialog.askopenfilename(initialdir="D:/isl_projects/datasets/", title="Select a Video File",filetypes=(("Video files", "*.mp4"),("all files", "*.*")))
    display_video(file_path)

def display_video(file_path):
    cap = cv2.VideoCapture(file_path)
    ret, frame = cap.read()
    if not ret:
        return
    h, w, channels = frame.shape
    scale_factor = 0.25  # Reduce the size by 4x
    h = int(h * scale_factor)
    w = int(w * scale_factor)
    video_label.config(width=w, height=h)
    video_label.pack()
    while ret:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, (w, h))
        img = Image.fromarray(frame)
        img_tk = ImageTk.PhotoImage(image=img)
        video_label.img_tk = img_tk
        video_label.config(image=img_tk)
        root.update()
        ret, frame = cap.read()
    cap.release()

video_label = tk.Label(root)

button1 = tk.Button(root, text="Choose File", command=choose_file)

button2 = tk.Button(root, text="Record Video", command=record_video)
button1.pack(side="top", pady=10)
button2.pack(side="bottom")
root.mainloop()

# %%
import tkinter as tk
import customtkinter as ck
import pandas as pd
import numpy as np
import pickle
import mediapipe as mp
import cv2
from PIL import Image,ImageTk
from tkinter import filedialog
import time


window = tk.Tk()
window.geometry("1000x1000")
window.title("isl")
ck.set_appearance_mode("dark")

wordlabel=ck.CTkLabel(window,height=20,width=120,padx=10,text_color='black',fg_color='blue')
wordlabel.place(x=10,y=1)
wordlabel.configure(text='word')
wordbox=ck.CTkLabel(window,height=20,width=120,padx=10,text_color='black',fg_color='blue')
wordbox.place(x=10,y=41)
wordbox.configure(text='0')

def select_file():
	global file_name
	file_name = filedialog.askopenfilename(initialdir="D:/isl_projects/datasets/", title="Select a Video File",
                                           filetypes=(("Video files", "*.mp4"),
                                                      ("all files", "*.*")))



button = ck.CTkButton(window,text='select_file',command=select_file,height=20,width=120,text_color='black',fg_color='blue')
button.place(x=10,y=650)

button1 = ck.CTkButton(window,text='capture',command=send_frames,height=20,width=120,text_color='black',fg_color='blue')
button1.place(x=10,y=690)

frame=tk.Frame(height=500,width=800)
frame.place(x=10,y=90)
lmain=tk.Label(frame)
lmain.place(x=0,y=0)

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_tracking_confidence=0.5, min_detection_confidence=0.5) 

cap = cv2.VideoCapture(0)

def detect():
    ret, frame = cap.read()
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) 
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640, 480))
    capture_time = 10
    start_time = time.time()
    while time.time() - start_time < capture_time:
        out.write(image)
    out.release()
    img = image 
    imgarr = Image.fromarray(img) 
    imgtk = ImageTk.PhotoImage(imgarr) 
    lmain.imgtk = imgtk 
    lmain.configure(image=imgtk)
    lmain.after(10, detect)  



detect()


window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 36
#      33 button = ck.CTkButton(window,text='select_file',command=select_file,height=20,width=120,text_color='black',fg_color='blue')
#      34 button.place(x=10,y=650)
# ---> 36 button1 = ck.CTkButton(window,text='capture',command=send_frames,height=20,width=120,text_color='black',fg_color='blue')
#      37 button1.place(x=10,y=690)
#      39 frame=tk.Frame(height=500,width=800)
#
# NameError: name 'send_frames' is not defined

# %%
import cv2
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import os

root = tk.Tk()
root.geometry("800x600")
root.configure(bg="yellow")
file_path=''
#This function should call the Python program that records webcam video using OpenCV.
def record_video():
    os.system('C:/Users/91790/Desktop/record.py')
    
def choose_file():
    file_path = filedialog.askopenfilename(initialdir="D:/isl_projects/datasets/", title="Select a Video File",
                                           filetypes=(("Video files", "*.mp4"),
                                                      ("all files", "*.*")))
    display_video(file_path)
    
def display_video(file_path):
    cap = cv2.VideoCapture(file_path)
    ret, frame = cap.read()
    if not ret:
        return
    h, w, channels = frame.shape
    scale_factor = 0.25  # Reduce the size by 4x
    h = int(h * scale_factor)
    w = int(w * scale_factor)
    video_canvas.config(width=w, height=h)
    video_canvas.pack()
    while ret:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, (w, h))
        img = Image.fromarray(frame)
        img_tk = ImageTk.PhotoImage(image=img)
        video_canvas.img_tk = img_tk
        video_canvas.create_image(0, 0, anchor=tk.NW, image=img_tk)
        root.update()
        ret, frame = cap.read()
    cap.release()

video_canvas = tk.Canvas(root)
video_canvas.pack()

button1 = tk.Button(root, text="Select Video", command=choose_file)
button1.pack()
button2 = tk.Button(root, text="Record Video", command=record_video)
button2.pack(side="bottom")
button3 = tk.Button(root, text="Record Video", command=predict(file_path))
button3.pack(side="bottom")
root.mainloop()
# Out:
# Traceback (most recent call last):
#
#   File D:\softwares\python310.5\lib\site-packages\IPython\core\interactiveshell.py:3442 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 6
#     from model import predict
#
#   File ~\Desktop\model.py:103
#     def(file_path)
#        ^
# SyntaxError: invalid syntax
